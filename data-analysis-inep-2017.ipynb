# %%
''' @author: Ana Cristina Lima (analimazn@gmail.com)

    Análise de dados sobre a quantidade de alunos:
        - Ingressos
        - Matriculados
        - Concluintes
    De acordo com a região para o ano de 2017.

    Dados disponibilizados pelo Inep nos seguintes links:
    http://inep.gov.br/inep-data
    https://inepdata.inep.gov.br/analytics/saw.dll?Dashboard
'''

# %%
# Bibliotecas utilizadas
import pandas as pd

# %%
# Variáveis utilizadas para preencher o dataframe
path = 'data/'
firstName = 'dado_de_'
files = {'ingressos', 'matriculas', 'concluintes'}
lastName = '_2017'
extension = '.csv'

# %%
# Função para preencher o dataframe com os dados presentes em .csv
def populateDataFrame(path, firstName, files, lastName, extension):
    dfList = list()

    for file in files:
        pd.set_option('max_colwidth', 8)
        df = pd.DataFrame(pd.read_csv(path+firstName+file+lastName+extension))
        dfList.append(df)

    df = pd.concat(dfList, sort=True)
    return df

# %%
# Dataframe gerado dos dados utilizados
df = populateDataFrame(path, firstName, files, lastName, extension)

# %%
''' Quantidade de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a REGIÃO 
'''
df.groupby(['REGIÃO', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].sum()
# Out:
# REGIÃO        CATEGORIA ADMINISTRATIVA  DADO
# CENTRO-OESTE  PRIVADA                   CONCLUINTE      228097
#                                         INGRESSO        258744
#                                         MATRICULADO     582979
#               PÚBLICA                   CONCLUINTE       67465
#                                         INGRESSO         58064
#                                         MATRICULADO     186788
# NORDESTE      PRIVADA                   CONCLUINTE      401531
#                                         INGRESSO        454532
#                                         MATRICULADO    1145134
#               PÚBLICA                   CONCLUINTE      203517
#                                         INGRESSO        167209
#                                         MATRICULADO     595986
# NORTE         PRIVADA                   CONCLUINTE      143104
#                                         INGRESSO        212371
#                                         MATRICULADO     477816
#               PÚBLICA                   CONCLUINTE       78992
#                                         INGRESSO         47203
#                                         MATRICULADO     195257
# SUDESTE       PRIVADA                   CONCLUINTE     1214755
#                                         INGRESSO       1270712
#                                         MATRICULADO    2964627
#               PÚBLICA                   CONCLUINTE      264466
#                                         INGRESSO        204760
#                                         MATRICULADO     720178
# SUL           PRIVADA                   CONCLUINTE      379578
#                                         INGRESSO        439672
#                                         MATRICULADO    1070221
#               PÚBLICA                   CONCLUINTE      113475
#                                         INGRESSO         94905
#                                         MATRICULADO     311769
# Name: QUANTIDADE, dtype: int64

# %%
''' Quantidade de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a UF 
'''
df.groupby(['UF', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].sum()
# Out:
# UF              CATEGORIA ADMINISTRATIVA  DADO
# ACRE            PRIVADA                   CONCLUINTE       10222
#                                           INGRESSO          9591
#                                           MATRICULADO      25294
#                 PÚBLICA                   CONCLUINTE        3971
#                                           INGRESSO          3474
#                                           MATRICULADO      11352
# ALAGOAS         PRIVADA                   CONCLUINTE       21338
#                                           INGRESSO         26397
#                                           MATRICULADO      63522
#                 PÚBLICA                   CONCLUINTE       10423
#                                           INGRESSO          8254
#                                           MATRICULADO      33379
# AMAPÁ           PRIVADA                   CONCLUINTE        8689
#                                           INGRESSO         17672
#                                           MATRICULADO      35071
#                 PÚBLICA                   CONCLUINTE        3779
#                                           INGRESSO          2080
#                                           MATRICULADO      12308
# AMAZONAS        PRIVADA                   CONCLUINTE       35419
#                                           INGRESSO         47927
#                                           MATRICULADO     114506
#                 PÚBLICA                   CONCLUINTE       19527
#                                           INGRESSO         10601
#                                           MATRICULADO      51592
# BAHIA           PRIVADA                   CONCLUINTE      105578
#                                           INGRESSO        129956
#                                           MATRICULADO     321661
#                 PÚBLICA                   CONCLUINTE       34262
#                                           INGRESSO         25945
#                                           MATRICULADO     106546
#                                                           ...
# RORAIMA         PRIVADA                   CONCLUINTE        4057
#                                           INGRESSO          8261
#                                           MATRICULADO      16349
#                 PÚBLICA                   CONCLUINTE        2805
#                                           INGRESSO          2631
#                                           MATRICULADO       9476
# SANTA CATARINA  PRIVADA                   CONCLUINTE       94927
#                                           INGRESSO        120494
#                                           MATRICULADO     291143
#                 PÚBLICA                   CONCLUINTE       23673
#                                           INGRESSO         19670
#                                           MATRICULADO      64639
# SERGIPE         PRIVADA                   CONCLUINTE       21839
#                                           INGRESSO         21107
#                                           MATRICULADO      55151
#                 PÚBLICA                   CONCLUINTE        8474
#                                           INGRESSO          6177
#                                           MATRICULADO      28138
# SÃO PAULO       PRIVADA                   CONCLUINTE      732041
#                                           INGRESSO        759644
#                                           MATRICULADO    1686567
#                 PÚBLICA                   CONCLUINTE      122011
#                                           INGRESSO         95317
#                                           MATRICULADO     296871
# TOCANTINS       PRIVADA                   CONCLUINTE       13172
#                                           INGRESSO         18851
#                                           MATRICULADO      44546
#                 PÚBLICA                   CONCLUINTE        8887
#                                           INGRESSO          7179
#                                           MATRICULADO      26393
# Name: QUANTIDADE, Length: 162, dtype: int64

# %%
''' Quantidade de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a SUB CATEGORIA ADMINISTRATIVA 
'''
df.groupby(['SUB CATEGORIA ADMINISTRATIVA', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].sum()
# Out:
# SUB CATEGORIA ADMINISTRATIVA  CATEGORIA ADMINISTRATIVA  DADO
# ESTADUAL                      PÚBLICA                   CONCLUINTE      242243
#                                                         INGRESSO        177654
#                                                         MATRICULADO     632117
# FEDERAL                       PÚBLICA                   CONCLUINTE      436916
#                                                         INGRESSO        367102
#                                                         MATRICULADO    1280721
# MUNICIPAL                     PÚBLICA                   CONCLUINTE       48756
#                                                         INGRESSO         27385
#                                                         MATRICULADO      97140
# PRIVADA                       PRIVADA                   CONCLUINTE     2367065
#                                                         INGRESSO       2636031
#                                                         MATRICULADO    6240777
# Name: QUANTIDADE, dtype: int64

# %%
''' Quantidade de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a SUB CATEGORIA ADMINISTRATIVA e REGIÃO
'''
df.groupby(['REGIÃO', 'SUB CATEGORIA ADMINISTRATIVA', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].sum()
# Out:
# REGIÃO        SUB CATEGORIA ADMINISTRATIVA  CATEGORIA ADMINISTRATIVA  DADO
# CENTRO-OESTE  ESTADUAL                      PÚBLICA                   CONCLUINTE       17104
#                                                                       INGRESSO         14857
#                                                                       MATRICULADO      44393
#               FEDERAL                       PÚBLICA                   CONCLUINTE       44970
#                                                                       INGRESSO         39396
#                                                                       MATRICULADO     129205
#               MUNICIPAL                     PÚBLICA                   CONCLUINTE        5391
#                                                                       INGRESSO          3811
#                                                                       MATRICULADO      13190
#               PRIVADA                       PRIVADA                   CONCLUINTE      228097
#                                                                       INGRESSO        258744
#                                                                       MATRICULADO     582979
# NORDESTE      ESTADUAL                      PÚBLICA                   CONCLUINTE       71450
#                                                                       INGRESSO         42776
#                                                                       MATRICULADO     183418
#               FEDERAL                       PÚBLICA                   CONCLUINTE      122521
#                                                                       INGRESSO        119666
#                                                                       MATRICULADO     395621
#               MUNICIPAL                     PÚBLICA                   CONCLUINTE        9546
#                                                                       INGRESSO          4767
#                                                                       MATRICULADO      16947
#               PRIVADA                       PRIVADA                   CONCLUINTE      401531
#                                                                       INGRESSO        454532
#                                                                       MATRICULADO    1145134
# NORTE         ESTADUAL                      PÚBLICA                   CONCLUINTE       17849
#                                                                       INGRESSO          8664
#                                                                       MATRICULADO      39290
#               FEDERAL                       PÚBLICA                   CONCLUINTE       59535
#                                                                       INGRESSO         37426
#                                                                       MATRICULADO     151474
#               MUNICIPAL                     PÚBLICA                   CONCLUINTE        1608
#                                                                       INGRESSO          1113
#                                                                       MATRICULADO       4493
#               PRIVADA                       PRIVADA                   CONCLUINTE      143104
#                                                                       INGRESSO        212371
#                                                                       MATRICULADO     477816
# SUDESTE       ESTADUAL                      PÚBLICA                   CONCLUINTE      100641
#                                                                       INGRESSO         83816
#                                                                       MATRICULADO     275994
#               FEDERAL                       PÚBLICA                   CONCLUINTE      138835
#                                                                       INGRESSO        106720
#                                                                       MATRICULADO     395150
#               MUNICIPAL                     PÚBLICA                   CONCLUINTE       24990
#                                                                       INGRESSO         14224
#                                                                       MATRICULADO      49034
#               PRIVADA                       PRIVADA                   CONCLUINTE     1214755
#                                                                       INGRESSO       1270712
#                                                                       MATRICULADO    2964627
# SUL           ESTADUAL                      PÚBLICA                   CONCLUINTE       35199
#                                                                       INGRESSO         27541
#                                                                       MATRICULADO      89022
#               FEDERAL                       PÚBLICA                   CONCLUINTE       71055
#                                                                       INGRESSO         63894
#                                                                       MATRICULADO     209271
#               MUNICIPAL                     PÚBLICA                   CONCLUINTE        7221
#                                                                       INGRESSO          3470
#                                                                       MATRICULADO      13476
#               PRIVADA                       PRIVADA                   CONCLUINTE      379578
#                                                                       INGRESSO        439672
#                                                                       MATRICULADO    1070221
# Name: QUANTIDADE, dtype: int64

# %%
''' Quantidade de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a SUB CATEGORIA ADMINISTRATIVA e UF
'''
df.groupby(['UF', 'SUB CATEGORIA ADMINISTRATIVA', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].sum()
# Out:
# UF         SUB CATEGORIA ADMINISTRATIVA  CATEGORIA ADMINISTRATIVA  DADO
# ACRE       FEDERAL                       PÚBLICA                   CONCLUINTE        3971
#                                                                    INGRESSO          3474
#                                                                    MATRICULADO      11352
#            PRIVADA                       PRIVADA                   CONCLUINTE       10222
#                                                                    INGRESSO          9591
#                                                                    MATRICULADO      25294
# ALAGOAS    ESTADUAL                      PÚBLICA                   CONCLUINTE        2880
#                                                                    INGRESSO          1488
#                                                                    MATRICULADO       7163
#            FEDERAL                       PÚBLICA                   CONCLUINTE        7543
#                                                                    INGRESSO          6766
#                                                                    MATRICULADO      26216
#            PRIVADA                       PRIVADA                   CONCLUINTE       21338
#                                                                    INGRESSO         26397
#                                                                    MATRICULADO      63522
# AMAPÁ      ESTADUAL                      PÚBLICA                   CONCLUINTE         702
#                                                                    INGRESSO           274
#                                                                    MATRICULADO       1542
#            FEDERAL                       PÚBLICA                   CONCLUINTE        3077
#                                                                    INGRESSO          1806
#                                                                    MATRICULADO      10766
#            PRIVADA                       PRIVADA                   CONCLUINTE        8689
#                                                                    INGRESSO         17672
#                                                                    MATRICULADO      35071
# AMAZONAS   ESTADUAL                      PÚBLICA                   CONCLUINTE        9204
#                                                                    INGRESSO          3537
#                                                                    MATRICULADO      19941
#            FEDERAL                       PÚBLICA                   CONCLUINTE       10323
#                                                                    INGRESSO          7064
#                                                                    MATRICULADO      31651
#                                                                                    ...
# SERGIPE    FEDERAL                       PÚBLICA                   CONCLUINTE        8474
#                                                                    INGRESSO          6177
#                                                                    MATRICULADO      28138
#            PRIVADA                       PRIVADA                   CONCLUINTE       21839
#                                                                    INGRESSO         21107
#                                                                    MATRICULADO      55151
# SÃO PAULO  ESTADUAL                      PÚBLICA                   CONCLUINTE       79396
#                                                                    INGRESSO         67337
#                                                                    MATRICULADO     199330
#            FEDERAL                       PÚBLICA                   CONCLUINTE       18548
#                                                                    INGRESSO         14616
#                                                                    MATRICULADO      51232
#            MUNICIPAL                     PÚBLICA                   CONCLUINTE       24067
#                                                                    INGRESSO         13364
#                                                                    MATRICULADO      46309
#            PRIVADA                       PRIVADA                   CONCLUINTE      732041
#                                                                    INGRESSO        759644
#                                                                    MATRICULADO    1686567
# TOCANTINS  ESTADUAL                      PÚBLICA                   CONCLUINTE        1487
#                                                                    INGRESSO           411
#                                                                    MATRICULADO       2311
#            FEDERAL                       PÚBLICA                   CONCLUINTE        5792
#                                                                    INGRESSO          5655
#                                                                    MATRICULADO      19589
#            MUNICIPAL                     PÚBLICA                   CONCLUINTE        1608
#                                                                    INGRESSO          1113
#                                                                    MATRICULADO       4493
#            PRIVADA                       PRIVADA                   CONCLUINTE       13172
#                                                                    INGRESSO         18851
#                                                                    MATRICULADO      44546
# Name: QUANTIDADE, Length: 263, dtype: int64

# %%
''' Média de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a UF 
'''
df.groupby(['UF', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].median()
# Out:
# UF              CATEGORIA ADMINISTRATIVA  DADO
# ACRE            PRIVADA                   CONCLUINTE      2739.0
#                                           INGRESSO        9591.0
#                                           MATRICULADO    25294.0
#                 PÚBLICA                   CONCLUINTE      1313.0
#                                           INGRESSO        3474.0
#                                           MATRICULADO    11352.0
# ALAGOAS         PRIVADA                   CONCLUINTE      6188.0
#                                           INGRESSO       26397.0
#                                           MATRICULADO    63522.0
#                 PÚBLICA                   CONCLUINTE       960.0
#                                           INGRESSO        4127.0
#                                           MATRICULADO    16689.5
# AMAPÁ           PRIVADA                   CONCLUINTE      2541.0
#                                           INGRESSO       17672.0
#                                           MATRICULADO    35071.0
#                 PÚBLICA                   CONCLUINTE       234.0
#                                           INGRESSO        1040.0
#                                           MATRICULADO     6154.0
# AMAZONAS        PRIVADA                   CONCLUINTE     11088.0
#                                           INGRESSO       47927.0
#                                           MATRICULADO    1145...
#                 PÚBLICA                   CONCLUINTE      3068.0
#                                           INGRESSO        5300.5
#                                           MATRICULADO    25796.0
# BAHIA           PRIVADA                   CONCLUINTE     29742.0
#                                           INGRESSO       1299...
#                                           MATRICULADO    3216...
#                 PÚBLICA                   CONCLUINTE      5451.0
#                                           INGRESSO       10818.0
#                                           MATRICULADO    47680.0
#                                                           ...
# RORAIMA         PRIVADA                   CONCLUINTE      1044.0
#                                           INGRESSO        8261.0
#                                           MATRICULADO    16349.0
#                 PÚBLICA                   CONCLUINTE       344.0
#                                           INGRESSO        1315.5
#                                           MATRICULADO     4738.0
# SANTA CATARINA  PRIVADA                   CONCLUINTE     25637.0
#                                           INGRESSO       1204...
#                                           MATRICULADO    2911...
#                 PÚBLICA                   CONCLUINTE      1959.0
#                                           INGRESSO        3963.0
#                                           MATRICULADO    13164.0
# SERGIPE         PRIVADA                   CONCLUINTE      6782.0
#                                           INGRESSO       21107.0
#                                           MATRICULADO    55151.0
#                 PÚBLICA                   CONCLUINTE      2781.0
#                                           INGRESSO        6177.0
#                                           MATRICULADO    28138.0
# SÃO PAULO       PRIVADA                   CONCLUINTE     2275...
#                                           INGRESSO       7596...
#                                           MATRICULADO    1686...
#                 PÚBLICA                   CONCLUINTE      6973.0
#                                           INGRESSO       14616.0
#                                           MATRICULADO    51232.0
# TOCANTINS       PRIVADA                   CONCLUINTE      3520.0
#                                           INGRESSO       18851.0
#                                           MATRICULADO    44546.0
#                 PÚBLICA                   CONCLUINTE       536.0
#                                           INGRESSO        1113.0
#                                           MATRICULADO     4493.0
# Name: QUANTIDADE, Length: 162, dtype: float64

# %%
''' Média de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a REGIÃO 
'''
df.groupby(['REGIÃO', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].median()
# Out:
# REGIÃO        CATEGORIA ADMINISTRATIVA  DADO
# CENTRO-OESTE  PRIVADA                   CONCLUINTE     13319.0
#                                         INGRESSO       66130.0
#                                         MATRICULADO    1522...
#               PÚBLICA                   CONCLUINTE      1879.0
#                                         INGRESSO        7671.0
#                                         MATRICULADO    18067.0
# NORDESTE      PRIVADA                   CONCLUINTE      8985.0
#                                         INGRESSO       32718.0
#                                         MATRICULADO    83354.0
#               PÚBLICA                   CONCLUINTE      2609.0
#                                         INGRESSO        8409.0
#                                         MATRICULADO    28138.0
# NORTE         PRIVADA                   CONCLUINTE      3129.5
#                                         INGRESSO       18851.0
#                                         MATRICULADO    44546.0
#               PÚBLICA                   CONCLUINTE      1006.0
#                                         INGRESSO        3441.0
#                                         MATRICULADO    11352.0
# SUDESTE       PRIVADA                   CONCLUINTE     56186.0
#                                         INGRESSO       2321...
#                                         MATRICULADO    5781...
#               PÚBLICA                   CONCLUINTE      2963.0
#                                         INGRESSO        8205.0
#                                         MATRICULADO    38138.0
# SUL           PRIVADA                   CONCLUINTE     31484.0
#                                         INGRESSO       1585...
#                                         MATRICULADO    3794...
#               PÚBLICA                   CONCLUINTE      1959.0
#                                         INGRESSO        8331.5
#                                         MATRICULADO    26386.5
# Name: QUANTIDADE, dtype: float64

# %%
# Biblioteca utilizada para gerar gráficos
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
''' Gráfico da quantidade de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a REGIÃO 
'''
df.groupby(['REGIÃO', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].sum().plot(kind ='bar', figsize = (11,5), grid = False, color = 'powderblue')

# %%
''' Gráfico da média de alunos ingressos, matriculados e concluintes 
    de instituições públicas e privadas de acordo com a REGIÃO 
'''
df.groupby(['REGIÃO', 'CATEGORIA ADMINISTRATIVA', 'DADO'])['QUANTIDADE'].median().plot(kind ='bar', figsize = (11,5), grid = False, color = 'powderblue')
